# %% [markdown]
# # Lift Gradient of a finite wing. Effect of stretching

# %%
# %matplotlib inline
# %run ./resources/init.py

# %% [markdown]
# Let us calculate the lift gradient $C_{L\alpha}$ of a finite wing and check the effect of the wing lenght.
# Let us assign the wing planform shape, i.e. let us assume given values of wing span $b$,tip chord lenght $c_\mathrm{t}$ and root chord lenght $c_\mathrm{r}$ .
# In python let us define the following variables :

# %%
c_r = 5.20; c_t=2.34; taper_ratio = c_r/c_t ;
b= 26.80 ; S = (c_r + c_t)*b/2 ; AR=b*b/S;
cl_alpha_root=6.15; cl_alpha_tip=6.05

# %%
Latex(
  r'\begin{array}{rl}'
    +  r'\text{Wing Span,}\, b: & ' + r'{0:.4}'.format(b) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{Reference Surface,}\, S: & ' + r'{0:.5}'.format(S) + r'\,\text{m}^2'
    +  r'\\'
    +  r'\text{Tip Chord,}\, c_\mathrm{t}: & ' + r'{0}'.format(c_t) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{Root Chord,}\, c_\mathrm{r}: & ' + r'{0}'.format(c_r) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{Aspect Ratio,}\, AR: & ' + r'{0:.4}'.format(AR) 
    +  r'\\'
  +r'\end{array}'
    )
# Out:
# \begin{array}{rl}\text{Wing Span,}\, b: & 26.8\,\text{m}\\\text{Reference Surface,}\, S: & 101.04\,\text{m}^2\\\text{Tip Chord,}\, c_\mathrm{t}: & 2.34\,\text{m}\\\text{Root Chord,}\, c_\mathrm{r}: & 5.2\,\text{m}\\\text{Aspect Ratio,}\, AR: & 7.109\\\end{array}

# %%
plot_planform(c_r,c_t,b)

# %% [markdown]
# The law of the chord is:
# \begin{equation}
# c(Y)=A_cY+B_c
# \end{equation}

# %% [markdown]
# The law of $C_{\ell\alpha}$ is:
# \begin{equation}
# C_{\ell,\alpha}=A_{C_{\ell\alpha}}Y+B_{C_{\ell\alpha}}
# \end{equation}

# %% [markdown]
# Let's calculate the coefficient:

# %%
A_c=2*(c_t-c_r)/b
B_c=c_r

# %% [markdown]
# So we have:

# %%
Latex(r'\begin{array}{ll}'
        +r'\\'
        + r'A_c=\dfrac{c_t-c_r}{b/2}=' 
        + r'{0:.3}' .format(A_c)
        + r'\\'     
        + r'B_c=c_r='
        + r'{0:.3}'.format(B_c)
        + r'\, \text{m}'
       + r'\end{array}'
        )
# Out:
# \begin{array}{ll}\\A_c=\dfrac{c_t-c_r}{b/2}=-0.213\\B_c=c_r=5.2\, \text{m}\end{array}

# %% [markdown]
# So we have:

# %%
display(Math(r'c(y) =\,' + '{0:.3}'.format(A_c) + '\,y + ' + '{0:.3}'.format(B_c) + r'\,\text{m}'))
# Out:
# $$c(y) =\,-0.213\,y + 5.2\,\text{m}$$

# %%
A_clalpha=2*(cl_alpha_tip-cl_alpha_root)/b
B_clalpha=cl_alpha_root

# %%
Latex(r'\begin{array}{ll}'
        +r'\\'
        + r'A_{C_{\ell\alpha}}=\dfrac{C_{\ell\alpha,t}-C_{\ell\alpha,r}}{b/2}=' 
        + r'{0:.3}' .format(A_clalpha)
        + r'\, (\text{rad m})^{-1}'
        + r'\\'     
        + r'B_{C_{\ell\alpha}}=C_{\ell\alpha,r}='
        + r'{0:.3}'.format(B_clalpha)
        + r'\, \text{rad}^{-1}'
       + r'\end{array}'
        )
# Out:
# \begin{array}{ll}\\A_{C_{\ell\alpha}}=\dfrac{C_{\ell\alpha,t}-C_{\ell\alpha,r}}{b/2}=-0.00746\, (\text{rad m})^{-1}\\B_{C_{\ell\alpha}}=C_{\ell\alpha,r}=6.15\, \text{rad}^{-1}\end{array}

# %% [markdown]
# So we have:

# %%
display(Math(r'C_{\ell\alpha}(Y) =\,' + '{0:.3}'.format(A_clalpha) + r'( \text{rad m})^{-1}\,y + ' + '{0:.3}'.format(B_clalpha) + r'\,\text{rad}^{-1}'))
# Out:
# $$C_{\ell\alpha}(Y) =\,-0.00746( \text{rad m})^{-1}\,y + 6.15\,\text{rad}^{-1}$$

# %% [markdown]
# We can now calculate an average gradient:

# %%
# symbolic variable
y = Symbol('y')
# indefinite integrals
c_lalphabar_law_integral_indefinite =  integrate( (A_c*y + B_c)*(A_clalpha*y+B_clalpha),y )
print('Indefinite integral : ' + str(c_lalphabar_law_integral_indefinite))
# definite integrals
c_lalphabar =  2/S*integrate((A_c*y + B_c)*(A_clalpha*y+B_clalpha),(y,0,b/2))
print('c_lalphabar = ' + '{0} '.format(c_lalphabar))
# Out:
# Indefinite integral : 0.000530927452290788*y**3 - 0.675708955223881*y**2 + 31.98*y
# c_lalphabar = 6.10632183908046

# %%
display_workflow_c_lalphabar(S,b,A_clalpha,B_clalpha,A_c,B_c,c_lalphabar_law_integral_indefinite,c_lalphabar)
# Out:
# \begin{align*}\bar{C_\mathrm{\ell_\mathrm{\alpha}}} & {}=\frac{2}{S} \int_{0}^{b/2} c(y)C_\mathrm{\ell_\alpha}(y) \, \mathrm{d}y\\& {}= \frac{2}{S} \int_{0}^{b/2} \big(A_cy + B_c\big)\,\big(A_\mathrm{C_{\ell\alpha}}y + B_\mathrm{C_{\ell\alpha}}\big)\, \mathrm{d}y\\& {}= \frac{2}{101.0\,\mathrm{m}^2} \int_0^{26.8}\Big(-0.2134\, y + 5.2\,\mathrm{m}\Big)\Big(-0.007463\,(\mathrm{rad}\,\mathrm{m})^{-1}\, y + 6.15\,\mathrm{rad}^{-1} \big)\, \mathrm{d}y\\[1em]& {}= \frac{2}{101.0\,\mathrm{m}^2} \big(0.000530927452290788 y^{3} - 0.675708955223881 y^{2} + 31.98 y\big)\Bigr|_0^{13.4}=6.106\,\mathrm{rad}^{-1}\end{align*}

# %%
eW=0.9
CLalpha=c_lalphabar/(1+c_lalphabar/(3.14*AR*eW))
Latex( 
  r'\begin{equation}'
    + r'C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}='
    + r'\dfrac{'
    + r'{0:.4}' .format(c_lalphabar)
    + r'\, \text{rad}^{-1}}{1+\dfrac{'
    + r'{0:.4}' .format(c_lalphabar)
    + r'\, \text{rad}^{-1}}{3.14\cdot'
    + r'{0:.3}' .format(AR)
    + r'\cdot'
    + r'{0:.3}'.format(eW)
    + r'}}=' 
    + r'{0:.4}' .format(CLalpha)
    + r'\,\text{rad}^{-1}'
  + r'\end{equation}'
)
# Out:
# \begin{equation}C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}=\dfrac{6.106\, \text{rad}^{-1}}{1+\dfrac{6.106\, \text{rad}^{-1}}{3.14\cdot7.11\cdot0.9}}=4.683\,\text{rad}^{-1}\end{equation}

# %% [markdown]
# Let us consider a wing with the same $c_\mathrm{r}$ and taper ratio $\lambda$ but with a different wing span, that we'll call $b'$ , that equals to $b$ reduced by 20%.

# %%
b1= b-0.20*b  
S1=(c_r + c_t)*b1/2 
AR1=b1*b1/S1

# %%
display(Math(r'\text{Wing span:}\quad b_1 = '+ '{0:.3}'.format(b1) +r'\,\text{m}'))
display(Math(r'\text{Aspect ratio:}\quad AR_1 = '+ '{0:.3}'.format(AR1)))
display(Math(r'\text{surface:}\quad S_1 = '+ '{0:.4}'.format(S1) +'\,\mathrm{m}^2'))
# Out:
# $$\text{Wing span:}\quad b_1 = 21.4\,\text{m}$$
# $$\text{Aspect ratio:}\quad AR_1 = 5.69$$
# $$\text{surface:}\quad S_1 = 80.83\,\mathrm{m}^2$$

# %%
A_c1=2*(c_t-c_r)/b1
B_c1=c_r
A_clalpha1=2*(cl_alpha_tip-cl_alpha_root)/b1
B_clalpha1=cl_alpha_root

# %% [markdown]
# So we have:

# %%
display(Math(r'c_1(y) =\,' + '{0:.3}'.format(A_c1) + '\,y + ' + '{0:.3}'.format(B_c1) + r'\,\text{m}'))
# Out:
# $$c_1(y) =\,-0.267\,y + 5.2\,\text{m}$$

# %%
display(Math(r'C_{\ell\alpha1}(Y) =\,' + '{0:.3}'.format(A_clalpha1) + r'( \text{rad m})^{-1}\,y + ' + '{0:.3}'.format(B_clalpha1) + r'\,\text{rad}^{-1}'))
# Out:
# $$C_{\ell\alpha1}(Y) =\,-0.00933( \text{rad m})^{-1}\,y + 6.15\,\text{rad}^{-1}$$

# %% [markdown]
# Let us now calculate the new $\bar{C}_{\ell\alpha}$ and $C_{L\alpha}$:

# %%
# symbolic variable
y = Symbol('y')
# indefinite integrals
c_lalphabar_law_integral_indefinite =  integrate( (A_c1*y + B_c1)*(A_clalpha1*y+B_clalpha1),y )
print('Indefinite integral : ' + str(c_lalphabar_law_integral_indefinite))
# definite integrals
c_lalphabar1 =  2/S1*integrate((A_c1*y + B_c1)*(A_clalpha1*y+B_clalpha1),(y,0,b1/2))
print('c_lalphabar1 = ' + '{0} '.format(c_lalphabar1))
# Out:
# Indefinite integral : 0.000829574144204356*y**3 - 0.844636194029851*y**2 + 31.98*y
# c_lalphabar1 = 6.10632183908046

# %%
display_workflow_c_lalphabar(S1,b1,A_clalpha1,B_clalpha1,A_c1,B_c1,c_lalphabar_law_integral_indefinite,c_lalphabar1)
# Out:
# \begin{align*}\bar{C_\mathrm{\ell_\mathrm{\alpha}}} & {}=\frac{2}{S} \int_{0}^{b/2} c(y)C_\mathrm{\ell_\alpha}(y) \, \mathrm{d}y\\& {}= \frac{2}{S} \int_{0}^{b/2} \big(A_cy + B_c\big)\,\big(A_\mathrm{C_{\ell\alpha}}y + B_\mathrm{C_{\ell\alpha}}\big)\, \mathrm{d}y\\& {}= \frac{2}{80.83\,\mathrm{m}^2} \int_0^{21.4}\Big(-0.2668\, y + 5.2\,\mathrm{m}\Big)\Big(-0.009328\,(\mathrm{rad}\,\mathrm{m})^{-1}\, y + 6.15\,\mathrm{rad}^{-1} \big)\, \mathrm{d}y\\[1em]& {}= \frac{2}{80.83\,\mathrm{m}^2} \big(0.000829574144204356 y^{3} - 0.844636194029851 y^{2} + 31.98 y\big)\Bigr|_0^{10.72}=6.106\,\mathrm{rad}^{-1}\end{align*}

# %%
CLalpha1=c_lalphabar1/(1+(c_lalphabar1/(3.14*AR1*eW)))
Latex( 
  r'\begin{equation}'
    + r'C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}='
    + r'\dfrac{'
    + r'{0:.4}' .format(c_lalphabar1)
    + r'\, \text{rad}^{-1}}{1+\dfrac{'
    + r'{0:.4}' .format(c_lalphabar)
    + r'\, \text{rad}^{-1}}{3.14\cdot'
    + r'{0:.3}' .format(AR1)
    + r'\cdot'
    + r'{0:.3}'.format(eW)
    + r'}}=' 
    + r'{0:.4}' .format(CLalpha1)
    + r'\,\text{rad}^{-1}'
  + r'\end{equation}'
)
# Out:
# \begin{equation}C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}=\dfrac{6.106\, \text{rad}^{-1}}{1+\dfrac{5.637\, \text{rad}^{-1}}{3.14\cdot5.69\cdot0.9}}=4.425\,\text{rad}^{-1}\end{equation}

# %% [markdown]
# Let's do the same for a wing with the same $c_\mathrm{r}$ and taperratio $\lambda$ but with a different wing span, that we'll call $b''$ , that equals to $b$ improved by 20%.

# %%
b2= b+0.20*b 
S2= (c_r + c_t)*b2/2
AR2=b2*b2/S2

# %%
display(Math(r'\text{Wing span:}\quad b_2 = '+ '{0:.3}'.format(b2) +r'\,\text{m}'))
display(Math(r'\text{Aspect ratio:}\quad AR_2 = '+ '{0:.3}'.format(AR2)))
display(Math(r'\text{surface:}\quad S_2 = '+ '{0:.4}'.format(S2) +'\,\mathrm{m}^2'))
# Out:
# $$\text{Wing span:}\quad b_2 = 32.2\,\text{m}$$
# $$\text{Aspect ratio:}\quad AR_2 = 8.53$$
# $$\text{surface:}\quad S_2 = 121.2\,\mathrm{m}^2$$

# %%
A_c2=2*(c_t-c_r)/b2
B_c2=c_r
A_clalpha2=2*(cl_alpha_tip-cl_alpha_root)/b2
B_clalpha2=cl_alpha_root

# %% [markdown]
# So we have:

# %%
display(Math(r'c_2(y) =\,' + '{0:.3}'.format(A_c2) + '\,y + ' + '{0:.3}'.format(B_c2) + r'\,\text{m}'))
# Out:
# $$c_2(y) =\,-0.178\,y + 5.2\,\text{m}$$

# %%
display(Math(r'C_{\ell\alpha2}(Y) =\,' + '{0:.3}'.format(A_clalpha2) + r'( \text{rad m})^{-1}\,y + ' + '{0:.3}'.format(B_clalpha2) + r'\,\text{rad}^{-1}'))
# Out:
# $$C_{\ell\alpha2}(Y) =\,-0.00622( \text{rad m})^{-1}\,y + 6.15\,\text{rad}^{-1}$$

# %% [markdown]
# Let us now calculate the new $\bar{C}_{\ell\alpha}$ and $C_{L\alpha}$:

# %%
# symbolic variable
y = Symbol('y')
# indefinite integrals
c_lalphabar_law_integral_indefinite =  integrate( (A_c2*y + B_c2)*(A_clalpha2*y+B_clalpha2),y )
print('Indefinite integral : ' + str(c_lalphabar_law_integral_indefinite))
# definite integrals
c_lalphabar2 =  2/S2*integrate((A_c2*y + B_c2)*(A_clalpha2*y+B_clalpha2),(y,0,b2/2))
print('c_lalphabar = ' + '{0} '.format(c_lalphabar2))
# Out:
# Indefinite integral : 0.00036869961964638*y**3 - 0.563090796019901*y**2 + 31.98*y
# c_lalphabar = 6.10632183908046

# %%
display_workflow_c_lalphabar(S2,b2,A_clalpha,B_clalpha,A_c,B_c,c_lalphabar_law_integral_indefinite,c_lalphabar2)
# Out:
# \begin{align*}\bar{C_\mathrm{\ell_\mathrm{\alpha}}} & {}=\frac{2}{S} \int_{0}^{b/2} c(y)C_\mathrm{\ell_\alpha}(y) \, \mathrm{d}y\\& {}= \frac{2}{S} \int_{0}^{b/2} \big(A_cy + B_c\big)\,\big(A_\mathrm{C_{\ell\alpha}}y + B_\mathrm{C_{\ell\alpha}}\big)\, \mathrm{d}y\\& {}= \frac{2}{121.2\,\mathrm{m}^2} \int_0^{32.2}\Big(-0.2134\, y + 5.2\,\mathrm{m}\Big)\Big(-0.009328\,(\mathrm{rad}\,\mathrm{m})^{-1}\, y + 6.15\,\mathrm{rad}^{-1} \big)\, \mathrm{d}y\\[1em]& {}= \frac{2}{121.2\,\mathrm{m}^2} \big(0.00036869961964638 y^{3} - 0.563090796019901 y^{2} + 31.98 y\big)\Bigr|_0^{16.08}=6.106\,\mathrm{rad}^{-1}\end{align*}

# %%
CLalpha2=c_lalphabar2/(1+c_lalphabar2/(3.14*AR2*eW))
Latex( 
  r'\begin{equation}'
    + r'C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}='
    + r'\dfrac{'
    + r'{0:.4}' .format(c_lalphabar2)
    + r'\, \text{rad}^{-1}}{1+\dfrac{'
    + r'{0:.4}' .format(c_lalphabar)
    + r'\, \text{rad}^{-1}}{3.14\cdot'
    + r'{0:.3}' .format(AR2)
    + r'\cdot'
    + r'{0:.3}'.format(eW)
    + r'}}=' 
    + r'{0:.4}' .format(CLalpha2)
    + r'\,\text{rad}^{-1}'
  + r'\end{equation}'
)
# Out:
# \begin{equation}C_{L\alpha}=\dfrac{\bar{C}_{\ell\alpha}}{1+\dfrac{\bar{C}_{\ell\alpha}}{\pi AR e_W}}=\dfrac{6.106\, \text{rad}^{-1}}{1+\dfrac{5.637\, \text{rad}^{-1}}{3.14\cdot8.53\cdot0.9}}=4.872\,\text{rad}^{-1}\end{equation}

# %% [markdown]
# We can see that for an increasing wing span $(AR'< AR < AR'')$ we have a bigger lift gradient of the wing ($C_{L\alpha}'<C_{L\alpha}<C_{L\alpha}'')$.

# %%
plot_planform_2(c_r,c_t,b,b1,b2,AR,AR1,AR2,CLalpha,CLalpha1,CLalpha2)
