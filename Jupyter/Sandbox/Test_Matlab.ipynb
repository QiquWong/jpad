% %% [markdown]
% # Matlab kernel test

% %% [markdown]
% Interact with Matlab in Notebook the using the ``Matlab engine for Python``. All commands are interpreted by Matlab. Since this is a MetaKernel, a standard set of magics are available. Help on commands is available using the %help magic or using ? with a command.
%
% <html>See the <a href="https://github.com/Calysto/matlab_kernel" target="_blank">Calysto Matlab kernel</a> for more infos.</html>

% %%
cd('matlab')
setup_prerequisites
cd('..')

% %%
clear all; close all; clc;
wingSurface = 3010 * str2u('ft^2')
wingSpan    = 146 * str2u('ft')
% Out:
% wingSurface =
%
%   279.6382
%
% 		 m^2
%
% wingSpan =
%
%    44.5008
%
% 		 m

% %%
t = linspace(0,6*pi,100);
plot(sin(t))
grid on
hold on
plot(cos(t), 'r')

% %%
% plot -s 200,150

% %%
b = 10*cos(t)+30; plot(b); grid on

% %%
a = [1,2,3]
% Out:
% a =
%
%      1     2     3

% %%
b = a + 3;

% %%
disp(b')
% Out:
%      4
%      5
%      6

% %%
%lsmagic
% Out:
% Available line magics:
% %activity  %cd  %connect_info  %conversation  %dot  %download  %edit  %get  %help  %html  %include  %install  %install_magic  %javascript  %jigsaw  %kernel  %kx  %latex  %load  %ls  %lsmagic  %macro  %magic  %matplotlib  %parallel  %plot  %pmap  %px  %python  %reload_magics  %restart  %run  %scheme  %set  %shell
%
% Available cell magics:
% %%activity  %%brain  %%conversation  %%debug  %%dot  %%file  %%help  %%html  %%javascript  %%kx  %%latex  %%macro  %%pipe  %%processing  %%px  %%python  %%scheme  %%shell  %%show  %%time  %%tutor

% %%
%%python
print('Hello, world!')
% Out:
% Hello, world!
